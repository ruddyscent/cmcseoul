# %% [markdown]
# # Jupyter Notebook Extensions

# %% [markdown]
# The following extensions, let you use a table of contents in the Jupyter Notebook.

# %%
# !pip install --upgrade jupyter_contrib_nbextensions jupyter_nbextensions_configurator
# Out:
# ...
#     100% |████████████████████████████████| 20.9MB 1.3MB/s eta 0:00:01   18% |██████                          | 3.9MB 23.8MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 481kB 16.6MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 870kB 16.3MB/s ta 0:00:01
# ...
#   Stored in directory: /Users/kwchun/Library/Caches/pip/wheels/15/df/fe/2a74fe34709e7fdc5ae153a768675d9fda93cc7d5133ed1fb0
# ...
#   Stored in directory: /Users/kwchun/Library/Caches/pip/wheels/0d/71/2a/164491997299b9f2479a251e254323fe35d946779e18f27956
# Successfully built jupyter-nbextensions-configurator jupyter-latex-envs
# ...

# %%
# !jupyter contrib nbextension install --user
# Out:
# [I 03:46:34 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 03:46:34 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 03:46:34 InstallContribNbextensionsApp] Installing /Users/kwchun/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband
# [I 03:46:34 InstallContribNbextensionsApp] Making directory: /Users/kwchun/Library/Jupyter/nbextensions/rubberband/
# [I 03:46:34 InstallContribNbextensionsApp] Copying: /Users/kwchun/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/icon.png -> /Users/kwchun/Library/Jupyter/nbextensions/rubberband/icon.png
# [I 03:46:34 InstallContribNbextensionsApp] Copying: /Users/kwchun/anaconda3/lib/python3.7/site-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/main.css -> /Users/kwchun/Library/Jupyter/nbextensions/rubberband/main.css
# ...

# %%
# !jupyter nbextensions_configurator enable --user
# Out:
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /Users/kwchun/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...

# %% [markdown]
# Now you need to shut down and launch Jupyter Notebook server to make the extensions take effect.

# %% [markdown]
# # Utilities

# %% [markdown]
# ## git

# %%
# !conda install --yes git

# %%
# !git config --global user.name "Kildong Hong"

# %%
# !git config --global user.email kildong@yuldoguk.go.kr

# %% [markdown]
# ## wget

# %%
# !conda install --yes wget

# %% [markdown]
# ## unzip

# %%
# !conda install --yes unzip

# %% [markdown]
# # Download lecture materials

# %% [markdown]
# ## Using git

# %%
# !git clone https://github.com/ruddyscent/cmcseoul.git

# %% [markdown]
# ## Using wget

# %%
# !wget https://github.com/ruddyscent/cmcseoul/archive/master.zip

# %%
# !unzip master.zip

# %%
# !mv cmcseoul-master cmcseoul
